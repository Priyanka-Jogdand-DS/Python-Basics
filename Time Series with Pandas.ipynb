# %%
from datetime import datetime

# %%
my_year = 2020
my_month= 3
my_day = 23
my_hour = 10
my_min = 13
my_sec = 35

# %%
my_date = datetime(my_year, my_month, my_day)

# %%
my_date
# Out:
# datetime.datetime(2020, 3, 23, 0, 0)

# %%
my_date_time = datetime(my_year, my_month, my_day, my_hour, my_min, my_sec)

# %%
my_date_time.day
# Out:
# 23

# %%
my_date_time.month
# Out:
# 3

# %%
my_date_time.hour
# Out:
# 10

# %%
my_date_time.second
# Out:
# 35

# %%
type(my_date_time)
# Out:
# datetime.datetime

# %%
import numpy as np

# %%
np.array(['2015-03-23','2016-03-23','2017-03-23'])
# Out:
# array(['2015-03-23', '2016-03-23', '2017-03-23'], dtype='<U10')

# %%
np.array(['2015-03-23','2016-03-23','2017-03-23'], dtype='datetime64')
# Out:
# array(['2015-03-23', '2016-03-23', '2017-03-23'], dtype='datetime64[D]')

# %%
np.array(['2015-03-23','2016-03-23','2017-03-23'], dtype='datetime64[Y]')
# Out:
# array(['2015', '2016', '2017'], dtype='datetime64[Y]')

# %%
np.array(['2015-03-23','2016-03-23','2017-03-23'], dtype='datetime64[M]')
# Out:
# array(['2015-03', '2016-03', '2017-03'], dtype='datetime64[M]')

# %%
np.array(['2015-03-23','2016-03-23','2017-03-23'], dtype='datetime64[D]')
# Out:
# array(['2015-03-23', '2016-03-23', '2017-03-23'], dtype='datetime64[D]')

# %%
np.array(['2015-03-23','2016-03-23','2017-03-23'], dtype='datetime64[h]')   # as we havn't provided hours data by default take display T00
# Out:
# array(['2015-03-23T00', '2016-03-23T00', '2017-03-23T00'],
#       dtype='datetime64[h]')

# %%
np.arange(0,10,2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.arange('2018-06-01','2018-06-23',7, dtype='datetime64[D]')
# Out:
# array(['2018-06-01', '2018-06-08', '2018-06-15', '2018-06-22'],
#       dtype='datetime64[D]')

# %%
np.arange('1968','1976', dtype='datetime64[Y]')
# Out:
# array(['1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975'],
#       dtype='datetime64[Y]')

# %%
import pandas as pd

# %%
pd.date_range('2020-01-01', periods=7, freq='D')
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.to_datetime(['2/1/2018','3/1/2018'], format='%d/%m/%Y')
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['2-1-2018','3-1-2018'], format='%d-%m-%Y')
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['2--1--2018','3--1--2018'], format='%d--%m--%Y')
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['2.1.2018','3.1.2018'], format='%d.%m.%Y')
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03'], dtype='datetime64[ns]', freq=None)

# %%
data=np.random.randn(3,2)
cols = ['A','B']
print(data)
# Out:
# [[ 0.14006394  0.10955307]
#  [-0.8093413  -0.23097065]
#  [ 0.88990768 -0.8122953 ]]

# %%
idx = pd.date_range('2020-01-01', periods=3, freq='D')

df=pd.DataFrame(data, index=idx, columns=cols)

# %%
df
# Out:
#                    A         B
# 2020-01-01  0.140064  0.109553
# 2020-01-02 -0.809341 -0.230971
# 2020-01-03  0.889908 -0.812295

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03'], dtype='datetime64[ns]', freq='D')

# %%
df.index.max()
# Out:
# Timestamp('2020-01-03 00:00:00')

# %%
df.index.argmax()
# Out:
# 2

# %%
df.index.min()
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
df.index.argmin()
# Out:
# 0

# %% [markdown]
# ## Time Resampling

# %%
df = pd.read_csv('C:\\Users\\Priyanka\\Desktop\\python2\\Time series\\UDEMY_TSA_FINAL\\Data\\starbucks.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006 entries, 0 to 1005
# Data columns (total 3 columns):
# Date      1006 non-null object
# Close     1006 non-null float64
# Volume    1006 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 23.7+ KB

# %%
df.head()
# Out:
#          Date    Close    Volume
# 0  2015-01-02  38.0061   6906098
# 1  2015-01-05  37.2781  11623796
# 2  2015-01-06  36.9748   7664340
# 3  2015-01-07  37.8848   9732554
# 4  2015-01-08  38.4961  13170548

# %%
df = pd.read_csv('C:\\Users\\Priyanka\\Desktop\\python2\\Time series\\UDEMY_TSA_FINAL\\Data\\starbucks.csv', index_col='Date', parse_dates=True)

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
# daily ---> yearly
df.resample(rule='A')

# %%
df.resample(rule='A').mean()
# Out:
#                 Close        Volume
# Date
# 2015-12-31  50.078100  8.649190e+06
# 2016-12-31  53.891732  9.300633e+06
# 2017-12-31  55.457310  9.296078e+06
# 2018-12-31  56.870005  1.122883e+07

# %%
df.resample(rule='A').std()
# Out:
#                Close        Volume
# Date
# 2015-12-31  6.076922  4.093368e+06
# 2016-12-31  1.958114  3.936798e+06
# 2017-12-31  2.415526  4.690972e+06
# 2018-12-31  4.678178  6.465358e+06

# %%
def first_day(entry):
    
    #IS THERE AN ENTRY?
    if len(entry):
        return entry[0]

# %%
df.resample(rule='A').apply(first_day)
# Out:
#               Close    Volume
# Date
# 2015-12-31  38.0061   6906098
# 2016-12-31  55.0780  13521544
# 2017-12-31  53.1100   7809307
# 2018-12-31  56.3243   7215978

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# ...             ...       ...
# 2018-12-24  60.5600   6323252
# 2018-12-26  63.0800  16646238
# 2018-12-27  63.2000  11308081
# 2018-12-28  63.3900   7712127
# 2018-12-31  64.4000   7690183
#
# [1006 rows x 2 columns]

# %%
# %matplotlib inline

df['Close'].resample('A').mean().plot.bar()

# %%
title = 'Monthly Max Closing Price for Starbucks'
df['Close'].resample('M').max().plot.bar(figsize=(16,6), title=title)

# %% [markdown]
# ## Time Shifting

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df.tail()
# Out:
#             Close    Volume
# Date
# 2018-12-24  60.56   6323252
# 2018-12-26  63.08  16646238
# 2018-12-27  63.20  11308081
# 2018-12-28  63.39   7712127
# 2018-12-31  64.40   7690183

# %%
df.shift(1).head()
# Out:
#               Close      Volume
# Date
# 2015-01-02      NaN         NaN
# 2015-01-05  38.0061   6906098.0
# 2015-01-06  37.2781  11623796.0
# 2015-01-07  36.9748   7664340.0
# 2015-01-08  37.8848   9732554.0

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df_shift =df.shift(5, fill_value=0) # shifted value will get replace by NaN value and we can fill NaN values by zero by fill_value

# %%
df_shift.head(10)
# Out:
#               Close    Volume
# Date
# 2015-01-02   0.0000         0
# 2015-01-05   0.0000         0
# 2015-01-06   0.0000         0
# 2015-01-07   0.0000         0
# 2015-01-08   0.0000         0
# 2015-01-09  38.0061   6906098
# 2015-01-12  37.2781  11623796
# 2015-01-13  36.9748   7664340
# 2015-01-14  37.8848   9732554
# 2015-01-15  38.4961  13170548

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df.shift(-1).tail()
# Out:
#             Close      Volume
# Date
# 2018-12-24  63.08  16646238.0
# 2018-12-26  63.20  11308081.0
# 2018-12-27  63.39   7712127.0
# 2018-12-28  64.40   7690183.0
# 2018-12-31    NaN         NaN

# %%
df.shift(-2).tail()
# Out:
#             Close      Volume
# Date
# 2018-12-24  63.20  11308081.0
# 2018-12-26  63.39   7712127.0
# 2018-12-27  64.40   7690183.0
# 2018-12-28    NaN         NaN
# 2018-12-31    NaN         NaN

# %%
df.shift(periods=1, freq='M').head()     # pushing every data to end of 1st month
# Out:
#               Close    Volume
# Date
# 2015-01-31  38.0061   6906098
# 2015-01-31  37.2781  11623796
# 2015-01-31  36.9748   7664340
# 2015-01-31  37.8848   9732554
# 2015-01-31  38.4961  13170548

# %%
df.shift(periods=2, freq='M').head()              # pushing every data to end of 2nd month
# Out:
#               Close    Volume
# Date
# 2015-02-28  38.0061   6906098
# 2015-02-28  37.2781  11623796
# 2015-02-28  36.9748   7664340
# 2015-02-28  37.8848   9732554
# 2015-02-28  38.4961  13170548

# %% [markdown]
# ## Rolling and Expanding

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df['Close'].plot(figsize=(12,5))

# %%
df.rolling(window=7).mean().head(10)
# Out:
#                 Close        Volume
# Date
# 2015-01-02        NaN           NaN
# 2015-01-05        NaN           NaN
# 2015-01-06        NaN           NaN
# 2015-01-07        NaN           NaN
# 2015-01-08        NaN           NaN
# 2015-01-09        NaN           NaN
# 2015-01-12  37.616786  1.238222e+07
# 2015-01-13  37.578786  1.297288e+07
# 2015-01-14  37.614786  1.264020e+07
# 2015-01-15  37.638114  1.270624e+07

# %%
df['Close'].plot(figsize=(12,5))
df.rolling(window=7).mean()['Close'].plot()

# %%
df['Close'].plot(figsize=(12,5))
df.rolling(window=30).mean()['Close'].plot()

# %%
df['Close'].plot(figsize=(12,5))
df.rolling(window=60).mean()['Close'].plot()

# %%
df['Close: 30 Day Mean'] = df['Close'].rolling(window=30).mean()

# %%
df.head()
# Out:
#               Close    Volume  Close: 30 Day Mean
# Date
# 2015-01-02  38.0061   6906098                 NaN
# 2015-01-05  37.2781  11623796                 NaN
# 2015-01-06  36.9748   7664340                 NaN
# 2015-01-07  37.8848   9732554                 NaN
# 2015-01-08  38.4961  13170548                 NaN

# %%
df[['Close', 'Close: 30 Day Mean']].plot(figsize=(12,5))

# %%
df['Close'].expanding().mean().plot(figsize=(12,5))

# %% [markdown]
# ## Visualizing Time Series Data

# %%
df = pd.read_csv('C:\\Users\\Priyanka\\Desktop\\python2\\Time series\\UDEMY_TSA_FINAL\\Data\\starbucks.csv', index_col='Date', parse_dates=True)

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df.plot()

# %%
df['Close'].plot();

# %%
df['Volume'].plot()

# %%
title = 'TITLE'
ylabel = 'Y LABEL'
xlabel= 'X LABEL'

# %%
ax = df['Close'].plot(figsize=(12,6), title=title)
ax.autoscale(axis='both', tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'Y LABEL'), Text(0.5, 0, 'X LABEL')]

# %%
ax = df['Close'].plot(figsize=(12,6), title=title)
ax.autoscale(axis='y', tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'Y LABEL'), Text(0.5, 0, 'X LABEL')]

# %%
df['Close'].plot(figsize=(12,4))

# %%
df['Close']
# Out:
# Date
# 2015-01-02    38.0061
# 2015-01-05    37.2781
# 2015-01-06    36.9748
# 2015-01-07    37.8848
# 2015-01-08    38.4961
#                ...
# 2018-12-24    60.5600
# 2018-12-26    63.0800
# 2018-12-27    63.2000
# 2018-12-28    63.3900
# 2018-12-31    64.4000
# Name: Close, Length: 1006, dtype: float64

# %%
df['Close']['2017-1-1':'2017-12-31']               #.plot(figsize=(12,4))
# Out:
# Date
# 2017-01-03    53.1100
# 2017-01-04    53.7241
# 2017-01-05    54.1750
# 2017-01-06    54.8179
# 2017-01-09    55.8446
#                ...
# 2017-12-22    56.0018
# 2017-12-26    55.8454
# 2017-12-27    55.9724
# 2017-12-28    56.5002
# 2017-12-29    56.1288
# Name: Close, Length: 251, dtype: float64

# %%
df['Close']['2017-1-1':'2017-12-31'].plot(figsize=(12,4))

# %%
df['Close'].plot(figsize=(12,4), xlim=['2017-1-1','2017-12-31'])

# %%
df['Close']['2017-1-1':'2017-12-31'].plot(figsize=(12,4), ylim=[0,70])

# %%
df['Close']['2017-1-1':'2017-12-31'].plot(figsize=(12,4), ylim=[40,70], ls='--', c='green')

# %%
from matplotlib import dates

# %%
df['Close'].plot(xlim=['2017-01-01','2017-03-01'])

# %%
# CREATE OUR AXIS OBJECT
ax = df['Close'].plot(xlim=['2017-01-01','2017-03-01'],ylim=[51,57])

# REMOVE PANDAS DEFAULT "Date" LABEL
ax.set(xlabel='')

# SET THE TICK LOCATOR AND FORMATTER FOR THE MAJOR AXIS
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0))
from datetime import datetime

# %%
ax = df['Close'].plot(xlim=['2017-01-01','2017-03-01'], ylim=[50,60], figsize=(12,5))
ax.set(xlabel='')
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0))
ax.xaxis.set_major_formatter(dates.DateFormatter("%a-%B-%d"))

ax.xaxis.set_minor_locator(dates.MonthLocator())
ax.xaxis.set_minor_formatter(dates.DateFormatter("%b"))

# %%
ax = df['Close'].plot(xlim=['2017-01-01','2017-03-01'], ylim=[50,60], figsize=(12,5))
ax.set(xlabel='')
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0))
ax.xaxis.set_major_formatter(dates.DateFormatter("%d"))

ax.xaxis.set_minor_locator(dates.MonthLocator())
ax.xaxis.set_minor_formatter(dates.DateFormatter("%b"))

# %%
ax = df['Close'].plot(xlim=['2017-01-01','2017-03-01'], ylim=[50,60], figsize=(12,5))
ax.set(xlabel='')
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0))
ax.xaxis.set_major_formatter(dates.DateFormatter("%d"))

ax.xaxis.set_minor_locator(dates.MonthLocator())
ax.xaxis.set_minor_formatter(dates.DateFormatter("\n\n%b"))


ax.yaxis.grid(True)
ax.xaxis.grid(True)

# %% [markdown]
# ## Time Series Excercise

# %%
# RUN THIS CELL
import pandas as pd
# %matplotlib inline

df = pd.read_csv('C:\\Users\\Priyanka\\Desktop\\python2\\Time series\\UDEMY_TSA_FINAL\\Data\\monthly_milk_production.csv', encoding='utf8')
title = "Monthly milk production: pounds per cow. Jan '62 - Dec '75"

print(len(df))
print(df.head())
# Out:
# 168
#       Date  Production
# 0  1962-01         589
# 1  1962-02         561
# 2  1962-03         640
# 3  1962-04         656
# 4  1962-05         727

# %% [markdown]
# #### 1. What is the current data type of the data column?

# %%
df.dtypes
# Out:
# Date          object
# Production     int64
# dtype: object

# %% [markdown]
# #### 2. Change the Date column to a datetime format

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date          datetime64[ns]
# Production             int64
# dtype: object

# %% [markdown]
# #### 3. Set the Date column to be the new index

# %%
df= df.set_index('Date')

# %%
df.head()
# Out:
#             Production
# Date
# 1962-01-01         589
# 1962-02-01         561
# 1962-03-01         640
# 1962-04-01         656
# 1962-05-01         727

# %% [markdown]
# #### 4. plot the dataframe with a simple line plot, what do you notice about the plot?

# %%
df.plot()

# %% [markdown]
# #### 5. Add a column called 'Month' that takes month value from the index

# %%
df['Month']= df.index.month

# %%
df.head()
# Out:
#             Production  Month
# Date
# 1962-01-01         589      1
# 1962-02-01         561      2
# 1962-03-01         640      3
# 1962-04-01         656      4
# 1962-05-01         727      5

# %%
# month in string format
#df['month_name'] = df.index.strftime('%B')

# %%
#df.head()

# %% [markdown]
# #### 6. Create a Boxplot that groups by the Month field

# %%
df.boxplot(by='Month', figsize=(12,5))

# %% [markdown]
# #### Read in the data UMTMVS.csv file from the Data folder

# %%
df = pd.read_csv('C:\\Users\\Priyanka\\Desktop\\python2\\Time series\\UDEMY_TSA_FINAL\\Data\\UMTMVS.csv')

# %%
#### Check the head of the data

# %%
df.head()
# Out:
#          DATE    UMTMVS
# 0  1992-01-01  209438.0
# 1  1992-02-01  232679.0
# 2  1992-03-01  249673.0
# 3  1992-04-01  239666.0
# 4  1992-05-01  243231.0

# %%
#### Set the DATE column as the index.

# %%
df = df.set_index('DATE')

# %%
df.head()
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %%
#### Check the data type of the index.

# %%
df.dtypes
# Out:
# UMTMVS    float64
# dtype: object

# %%
#### Convert the index to be a datetime index. Note, there are many, many correct ways to do this!

# %%
df.index = pd.to_datetime(df.index)

# %%
df.index
# Out:
# DatetimeIndex(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01',
#                '1992-05-01', '1992-06-01', '1992-07-01', '1992-08-01',
#                '1992-09-01', '1992-10-01',
#                ...
#                '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01',
#                '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01',
#                '2018-12-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='DATE', length=325, freq=None)

# %%
#### Plot out the data, choose a reasonable figure size

# %%
df.plot(figsize=(15,8))

# %%
df.head()
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %%
#### What was the percent increase in value from Jan 2009 to Jan 2019?

# %%
100 * (df.loc['2019-01-01'] - df.loc['2009-01-01']) / df.loc['2009-01-01']
# Out:
# UMTMVS    38.472149
# dtype: float64

# %%
#### What was the percent decrease from jan 2008 to jan 2009?

# %%
100 * (df.loc['2009-01-01'] - df.loc['2008-01-01']) / df.loc['2008-01-01']
# Out:
# UMTMVS   -22.022775
# dtype: float64

# %%
#### What is the month with the least value after 2005?

# %%
df.loc['2005-01-01':].idxmin()
# Out:
# UMTMVS   2009-01-01
# dtype: datetime64[ns]

# %%
#### What 6 months have the highest value?

# %%
df.sort_values(by='UMTMVS', ascending=False).head(6)
# Out:
#               UMTMVS
# DATE
# 2018-08-01  529157.0
# 2018-10-01  527031.0
# 2018-06-01  525660.0
# 2018-03-01  518285.0
# 2018-09-01  516992.0
# 2014-06-01  516935.0

# %%
#### How many millions of dollars in value was lost in 2008? (Another way of posing this question is what was the value difference between Jan 2008 and Jan 2009)

# %%
df.loc['2008-01-01'] - df.loc['2009-01-01']
# Out:
# UMTMVS    95206.0
# dtype: float64

# %%
#### Create a bar plot showing the average value in millions of dollars per year

# %%
df.resample('Y').mean().plot.bar(figsize=(12,8))

# %%
#### What year had the biggest increase in mean value from the previous year's mean value? (Lots of ways to get this answer!)

# %%
yearly_data = df.resample('Y').mean()

# %%
yearly_data.head()
# Out:
#                    UMTMVS
# DATE
# 1992-12-31  242002.000000
# 1993-12-31  251708.083333
# 1994-12-31  269842.666667
# 1995-12-31  289973.083333
# 1996-12-31  299765.666667

# %%
yearly_data_shift = yearly_data.shift(1)

# %%
change =  yearly_data - yearly_data_shift

# %%
change.head()
# Out:
#                   UMTMVS
# DATE
# 1992-12-31           NaN
# 1993-12-31   9706.083333
# 1994-12-31  18134.583333
# 1995-12-31  20130.416667
# 1996-12-31   9792.583333

# %%
change['UMTMVS'].idxmax()
# Out:
# Timestamp('2011-12-31 00:00:00', freq='A-DEC')

# %%
#### Plot the yearly rolling mean on top of the original data. Recall that this is monthly data and there are 12 months in a year

# %%
df['Yearly Mean'] = df['UMTMVS'].rolling(window=12).mean()

# %%
df.plot(figsize=(12,5))

# %%
#### BONUS QUESTION (HARD).

#### Some month in 2008 the value peaked for that year. How many months did it take to surpass that 2008 peak? 
#### (Since it crashed immediately after this peak) There are many ways to get this answer. 
#### NOTE: I get 70 months as my answer, you may get 69 or 68, depending on whether or not you count the start and end months. 
#### Refer to the video solutions for full explanation on this.

# %%
df = pd.read_csv('C:\\Users\\Priyanka\\Desktop\\python2\\Time series\\UDEMY_TSA_FINAL\\Data\\UMTMVS.csv', index_col='DATE', parse_dates=True)

# %%
df.head()
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %%
df_2008 = df.loc['2008-01-01':'2008-12-01']

# %%
df_2008
# Out:
#               UMTMVS
# DATE
# 2008-01-01  432307.0
# 2008-02-01  442996.0
# 2008-03-01  474592.0
# 2008-04-01  475667.0
# 2008-05-01  490500.0
# 2008-06-01  510081.0
# 2008-07-01  476948.0
# 2008-08-01  482530.0
# 2008-09-01  471799.0
# 2008-10-01  450521.0
# 2008-11-01  383475.0
# 2008-12-01  377578.0

# %%
df_2008.idxmax()
# Out:
# UMTMVS   2008-06-01
# dtype: datetime64[ns]

# %%
df_2008.max()
# Out:
# UMTMVS    510081.0
# dtype: float64

# %%
df_post_peak = df.loc['2008-06-01':]

# %%
df_post_peak[df_post_peak>510081.0]
# Out:
#               UMTMVS
# DATE
# 2008-06-01       NaN
# 2008-07-01       NaN
# 2008-08-01       NaN
# 2008-09-01       NaN
# 2008-10-01       NaN
# ...              ...
# 2018-09-01  516992.0
# 2018-10-01  527031.0
# 2018-11-01       NaN
# 2018-12-01       NaN
# 2019-01-01       NaN
#
# [128 rows x 1 columns]

# %%
df_post_peak[df_post_peak>510081.0].dropna()
# Out:
#               UMTMVS
# DATE
# 2014-03-01  513700.0
# 2014-06-01  516935.0
# 2014-09-01  512988.0
# 2018-03-01  518285.0
# 2018-05-01  515105.0
# 2018-06-01  525660.0
# 2018-08-01  529157.0
# 2018-09-01  516992.0
# 2018-10-01  527031.0

# %%
df.loc['2008-01-01':'2014-03-01']
# Out:
#               UMTMVS
# DATE
# 2008-01-01  432307.0
# 2008-02-01  442996.0
# 2008-03-01  474592.0
# 2008-04-01  475667.0
# 2008-05-01  490500.0
# ...              ...
# 2013-11-01  475238.0
# 2013-12-01  476957.0
# 2014-01-01  451848.0
# 2014-02-01  457671.0
# 2014-03-01  513700.0
#
# [75 rows x 1 columns]

# %%
len(df.loc['2008-01-01':'2014-03-01'])
# Out:
# 75
