# %% [markdown]
# # Generate Time Sequence

# %%
import pandas as pd

# %%
pd.date_range(start = '2020-01-01', end = '2020-03-31', freq='D')
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31', '2020-02-01',
#                '2020-02-02', '2020-02-03', '2020-02-04', '2020-02-05',
#                '2020-02-06', '2020-02-07', '2020-02-08', '2020-02-09',
#                '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13',
#                '2020-02-14', '2020-02-15', '2020-02-16', '2020-02-17',
#                '2020-02-18', '2020-02-19', '2020-02-20', '2020-02-21',
# ...

# %%
pd.date_range(start = '2020-01-01', end = '2020-03-31', freq='W')
# Out:
# DatetimeIndex(['2020-01-05', '2020-01-12', '2020-01-19', '2020-01-26',
#                '2020-02-02', '2020-02-09', '2020-02-16', '2020-02-23',
#                '2020-03-01', '2020-03-08', '2020-03-15', '2020-03-22',
#                '2020-03-29'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
    pd.date_range(start = '2020-01-01', end = '2020-03-31', freq='W-MON')
# Out:
# DatetimeIndex(['2020-01-06', '2020-01-13', '2020-01-20', '2020-01-27',
#                '2020-02-03', '2020-02-10', '2020-02-17', '2020-02-24',
#                '2020-03-02', '2020-03-09', '2020-03-16', '2020-03-23',
#                '2020-03-30'],
#               dtype='datetime64[ns]', freq='W-MON')

# %%
pd.date_range(start = '2020-01-01', end = '2020-03-31', freq='B')
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-20', '2020-01-21', '2020-01-22',
#                '2020-01-23', '2020-01-24', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31', '2020-02-03',
#                '2020-02-04', '2020-02-05', '2020-02-06', '2020-02-07',
#                '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13',
#                '2020-02-14', '2020-02-17', '2020-02-18', '2020-02-19',
#                '2020-02-20', '2020-02-21', '2020-02-24', '2020-02-25',
#                '2020-02-26', '2020-02-27', '2020-02-28', '2020-03-02',
#                '2020-03-03', '2020-03-04', '2020-03-05', '2020-03-06',
#                '2020-03-09', '2020-03-10', '2020-03-11', '2020-03-12',
# ...

# %%
pd.date_range(start = '2020-01-01', end = '2020-03-31', freq='M')
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31'], dtype='datetime64[ns]', freq='M')

# %%
pd.date_range(start = '2020-01-01', end = '2020-03-31', freq='H')
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 01:00:00',
#                '2020-01-01 02:00:00', '2020-01-01 03:00:00',
#                '2020-01-01 04:00:00', '2020-01-01 05:00:00',
#                '2020-01-01 06:00:00', '2020-01-01 07:00:00',
#                '2020-01-01 08:00:00', '2020-01-01 09:00:00',
#                ...
#                '2020-03-30 15:00:00', '2020-03-30 16:00:00',
#                '2020-03-30 17:00:00', '2020-03-30 18:00:00',
#                '2020-03-30 19:00:00', '2020-03-30 20:00:00',
#                '2020-03-30 21:00:00', '2020-03-30 22:00:00',
#                '2020-03-30 23:00:00', '2020-03-31 00:00:00'],
#               dtype='datetime64[ns]', length=2161, freq='H')

# %%
pd.date_range(start = '2020-01-01', end = '2020-03-31', freq='6H')
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 06:00:00',
#                '2020-01-01 12:00:00', '2020-01-01 18:00:00',
#                '2020-01-02 00:00:00', '2020-01-02 06:00:00',
#                '2020-01-02 12:00:00', '2020-01-02 18:00:00',
#                '2020-01-03 00:00:00', '2020-01-03 06:00:00',
#                ...
#                '2020-03-28 18:00:00', '2020-03-29 00:00:00',
#                '2020-03-29 06:00:00', '2020-03-29 12:00:00',
#                '2020-03-29 18:00:00', '2020-03-30 00:00:00',
#                '2020-03-30 06:00:00', '2020-03-30 12:00:00',
#                '2020-03-30 18:00:00', '2020-03-31 00:00:00'],
#               dtype='datetime64[ns]', length=361, freq='6H')

# %%
pd.date_range(start = '2020-01-01', periods = 10, freq='6H')
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 06:00:00',
#                '2020-01-01 12:00:00', '2020-01-01 18:00:00',
#                '2020-01-02 00:00:00', '2020-01-02 06:00:00',
#                '2020-01-02 12:00:00', '2020-01-02 18:00:00',
#                '2020-01-03 00:00:00', '2020-01-03 06:00:00'],
#               dtype='datetime64[ns]', freq='6H')

# %%
pd.date_range(start = '2020-01-01', periods = 10, freq='B')
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14'],
#               dtype='datetime64[ns]', freq='B')
